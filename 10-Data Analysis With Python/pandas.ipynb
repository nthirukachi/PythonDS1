# %%
import pandas as pd
s=pd.Series([1, 2, 3, 4, 5])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data=pd.read_csv('data.csv')  # Example of reading a CSV file
print(data)  # Display the first few rows of the DataFrame
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    NaN   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    NaN  Product1  895.0  North
# ...

# %%
d=pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})  
print(d)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')  # Reading a CSV file into a DataFrame

# %%
df.info()  # Displaying information about the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df.head(5)  # Displaying the first few rows of the DataFrame
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.describe()  # Generating descriptive statistics of the DataFrame
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()  # Checking for missing values in the DataFrame
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df[['age', 'sex', 'survived']].head()  # Selecting specific columns from the DataFrame
# Out:
#     age     sex  survived
# 0  22.0    male         0
# 1  38.0  female         1
# 2  26.0  female         1
# 3  35.0  female         1
# 4  35.0    male         0

# %%
df[df['survived'] == 1].head()  # Filtering the DataFrame for survivors
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
df['age'].mean()  # Calculating the mean of the 'Age' column
# Out:
# np.float64(29.69911764705882)

# %%
df[df['embarked'] == 'S'].head()  # Filtering the DataFrame for passengers who embarked at Southampton
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 6    man        True    E  Southampton    no   True

# %%
df[df['embarked'].isin(['S', 'C'])].head()  # Filtering for passengers who embarked at Southampton or Cherbourg
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['embarked'].value_counts()  # Counting the occurrences of each embarkation point
# Out:
# embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['embarked'].unique()  # Getting unique values in the 'embarked' column
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['embarked'].nunique()  # Counting the number of unique values in the 'embarked' column
# Out:
# 3

# %%
pd.crosstab(df['sex'], df['survived'])  # Creating a cross-tabulation
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
pd.crosstab(df['sex'], df['embarked'])  # Cross-tabulation of '
# Out:
# embarked   C   Q    S
# sex
# female    73  36  203
# male      95  41  441

# %%
df[~df['embarked'].isin(['S', 'C'])].head()  # Filtering for passengers who did not embark at Southampton or Cherbourg
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 5          0       3    male   NaN      0      0   8.4583        Q  Third
# 16         0       3    male   2.0      4      1  29.1250        Q  Third
# 22         1       3  female  15.0      0      0   8.0292        Q  Third
# 28         1       3  female   NaN      0      0   7.8792        Q  Third
# 32         1       3  female   NaN      0      0   7.7500        Q  Third
#
#       who  adult_male deck embark_town alive  alone
# 5     man        True  NaN  Queenstown    no   True
# 16  child       False  NaN  Queenstown    no  False
# 22  child       False  NaN  Queenstown   yes   True
# 28  woman       False  NaN  Queenstown   yes   True
# 32  woman       False  NaN  Queenstown   yes   True

# %%
df[~df['embarked'].isin(['S', 'C'])].count()  # Counting the number of passengers who did not embark at Southampton or Cherbourg
# Out:
# survived       79
# pclass         79
# sex            79
# age            30
# sibsp          79
# parch          79
# fare           79
# embarked       77
# class          79
# who            79
# adult_male     79
# deck            6
# embark_town    77
# alive          79
# alone          79
# dtype: int64

# %%
df[(df['sex'] == 'male') & (df['pclass'] == 3) & (df['fare'] > 20)]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  \
# 7           0       3  male   2.0      3      1  21.0750        S  Third
# 13          0       3  male  39.0      1      5  31.2750        S  Third
# 16          0       3  male   2.0      4      1  29.1250        Q  Third
# 48          0       3  male   NaN      2      0  21.6792        C  Third
# 50          0       3  male   7.0      4      1  39.6875        S  Third
# 59          0       3  male  11.0      5      2  46.9000        S  Third
# 63          0       3  male   4.0      3      2  27.9000        S  Third
# 74          1       3  male  32.0      0      0  56.4958        S  Third
# 86          0       3  male  16.0      1      3  34.3750        S  Third
# 93          0       3  male  26.0      1      2  20.5750        S  Third
# 159         0       3  male   NaN      8      2  69.5500        S  Third
# 164         0       3  male   1.0      4      1  39.6875        S  Third
# ...

# %%
df[(df['age'] < 10) & (df['survived'] == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 58          1       2  female  5.00      1      2   27.7500        S  Second
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 165         1       3    male  9.00      0      2   20.5250        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# 184         1       3  female  4.00      0      2   22.0250        S   Third
# 193         1       2    male  3.00      1      1   26.0000        S  Second
# 233         1       3  female  5.00      4      2   31.3875        S   Third
# 237         1       2  female  8.00      0      2   26.2500        S  Second
# ...

# %%
df[(df['sex'] =='male') & (df['class'].str.lo == 'Third') & (df['fare'] > 20)].head()  # Filtering
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  \
# 7          0       3  male   2.0      3      1  21.0750        S  Third
# 13         0       3  male  39.0      1      5  31.2750        S  Third
# 16         0       3  male   2.0      4      1  29.1250        Q  Third
# 48         0       3  male   NaN      2      0  21.6792        C  Third
# 50         0       3  male   7.0      4      1  39.6875        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 13    man        True  NaN  Southampton    no  False
# 16  child       False  NaN   Queenstown    no  False
# 48    man        True  NaN    Cherbourg    no  False
# 50  child       False  NaN  Southampton    no  False

# %%
high_fare_mask = df['fare'] > 50  # Define mask for high fare passengers
high_fare = df[high_fare_mask]    # Filter DataFrame using the mask
high_fare                         # Display the result
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 6           0       1    male  54.0      0      0   51.8625        S  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 31          1       1  female   NaN      1      0  146.5208        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 867         0       1    male  31.0      0      0   50.4958        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.groupby(['sex', 'class'])['survived'].mean()
# Out:
# sex     class
# female  First     0.968085
#         Second    0.921053
#         Third     0.500000
# male    First     0.368852
#         Second    0.157407
#         Third     0.135447
# Name: survived, dtype: float64

# %%
df.groupby('embarked').agg({'age': 'mean', 'fare': 'mean'})  # Aggregating data by 'embarked' column
# Out:
#                 age       fare
# embarked
# C         30.814769  59.954144
# Q         28.089286  13.276030
# S         29.445397  27.079812

# %%
df.groupby('embarked')[['age', 'fare']].mean()
# Out:
#                 age       fare
# embarked
# C         30.814769  59.954144
# Q         28.089286  13.276030
# S         29.445397  27.079812

# %%
df['sex'].value_counts()  # Counting occurrences
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)  # Calculating the correlation matrix
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
df.nlargest(5, 'fare')  # Getting the top 5 rows with the highest fare
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 737    man        True    B    Cherbourg   yes   True
# 27     man        True    C  Southampton    no  False
# 88   woman       False    C  Southampton   yes  False
