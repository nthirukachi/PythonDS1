# %% [markdown]
# # 📘 Decision Tree - Detailed Teaching Edition
#
# ### 🧩 Problem Statement
# - **What problem is being solved?** Creating a rule-based classifier.
# - **Why it matters?** Transparency. We can see *why* a decision was made.
# - **Real-world relevance:** Credit Scoring, Medical Flows.
#
# ### 🪜 Steps to Solve the Problem
# 1. **Load Data.**
# 2. **Preprocess.**
# 3. **Split.**
# 4. **Train Tree (Find best questions).**
# 5. **Visualize.**
#
# ### 🎯 Expected Output
# - A flowchart that explains customer behavior.

# %% [markdown]
# # PART A: DATA PREPROCESSING

# %% [markdown]
# ### 🔹 Line Explanation
# #### 2.1 What the line does
# Imports plot_tree.
# #### 2.2 Why it is used
# To draw the flowchart.
# #### 2.3 When to use it
# After training a tree.
# #### 2.4 Where to use it
# Visualization step.
# #### 2.5 How to use it
# `plot_tree(model)`
# #### 2.6 How it works internally
# Traverses the node structure and draws boxes via matplotlib.
# #### 2.7 Output with sample examples
# An image.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
FILE_PATH = 'C:/nagpython/demouv/CustomerPurchaseBehavior/data/customer_behavior.csv'
df = pd.read_csv(FILE_PATH)
X = df.drop('PurchaseCategory', axis=1)
y = df['PurchaseCategory']

# %%
numeric_features = ['Age', 'Income', 'MonthlySpending', 'SessionDuration', 'PageViewsPerVisit', 'AccountAge']
categorical_features = ['DeviceType', 'MembershipTier']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# # PART B: MODEL IMPLEMENTATION

# %% [markdown]
# ### ⚙️ Function / Method Arguments Explanation
# **Function:** `DecisionTreeClassifier`
# **Argument 1:** `max_depth=4`
# - **3.1 What it does:** Sets max number of questions.
# - **3.2 Why it is used:** To keep the tree simple.
# - **3.3 When to use it:** Always.
# - **3.4 Where to use it:** Constructor.
# - **3.5 How to use it:** `max_depth=4`.
# - **3.6 Internal Effect:** Stops splitting.
# - **3.7 Output impact:** Prevents monster trees.
#
# **Argument 2:** `class_weight='balanced'`
# - **3.1 What it does:** Weights rare classes higher.
# - **3.2 Why it is used:** Imbalance handling.
# - **3.3 When to use it:** When data is skewed.
# - **3.4 Where to use it:** Constructor.
# - **3.5 How to use it:** `class_weight='balanced'`.
# - **3.6 Internal Effect:** Multiplies loss function.

# %%
dt_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', DecisionTreeClassifier(max_depth=4, class_weight='balanced', random_state=42))
])

print("Training Tree...")
dt_pipeline.fit(X_train, y_train)
print("Done!")

# %%
y_pred = dt_pipeline.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc:.4f}")

# %% [markdown]
# # PART C: COMPARISON

# %% [markdown]
# ### ❓ Question 8: Confusion Matrix
# Does it find the Sports fans? Yes, better than KNN because of the weights.

# %% [markdown]
# ### ❓ Question 9: Misleading Metrics
# Accuracy might drop, but Recall rises. That is a good trade for this problem.

# %% [markdown]
# ### ❓ Question 10: Recommendation
# Use Single Trees for Data Analysis. Use Random Forest for Prediction.

# %% [markdown]
# ### ❓ Question 11: Improvements
# 1. **CCP Pruning** (Cost Complexity Pruning).
# 2. **Minimum Samples Split** (Require 100 people before asking a new question).
