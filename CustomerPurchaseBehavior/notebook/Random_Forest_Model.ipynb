# %% [markdown]
# # 📘 Random Forest - Detailed Teaching Edition
#
# ### 🧩 Problem Statement
# - **What problem is being solved?** Determining purchase probability using a crowd of trees.
# - **Why it matters?** To get the most accurate result possible.
# - **Real-world relevance:** Microsoft Kinect, Stock Trading.
#
# ### 🪜 Steps to Solve the Problem
# 1. **Load Data.**
# 2. **Preprocess.**
# 3. **Split.**
# 4. **Train Forest (100 Trees).**
# 5. **Evaluate (Vote).**
#
# ### 🎯 Expected Output
# - High Accuracy >90%.

# %% [markdown]
# # PART A: DATA PREPROCESSING

# %% [markdown]
# ### 🔹 Line Explanation
# #### 2.1 What the line does
# Imports RandomForestClassifier.
# #### 2.2 Why it is used
# Ensemble learning.
# #### 2.3 When to use it
# When single trees fail.
# #### 2.4 Where to use it
# From sklearn.ensemble.
# #### 2.5 How to use it
# Import statement.
# #### 2.6 How it works internally
# Imports the bagging algorithm class.
# #### 2.7 Output with sample examples
# Class.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
FILE_PATH = 'C:/nagpython/demouv/CustomerPurchaseBehavior/data/customer_behavior.csv'
df = pd.read_csv(FILE_PATH)
X = df.drop('PurchaseCategory', axis=1)
y = df['PurchaseCategory']

# %%
numeric_features = ['Age', 'Income', 'MonthlySpending', 'SessionDuration', 'PageViewsPerVisit', 'AccountAge']
categorical_features = ['DeviceType', 'MembershipTier']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# # PART B: MODEL IMPLEMENTATION

# %% [markdown]
# ### ⚙️ Function / Method Arguments Explanation
# **Function:** `RandomForestClassifier`
# **Argument 1:** `n_estimators=100`
# - **3.1 What it does:** Number of trees to grow.
# - **3.2 Why it is used:** More is better (up to a point).
# - **3.3 When to use it:** Always.
# - **3.4 Where to use it:** Constructor.
# - **3.5 How to use it:** `100`.
# - **3.6 Internal Effect:** Defines loop count.
# - **3.7 Output impact:** Stability.

# %%
rf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42))
])

print("Training Forest...")
rf_pipeline.fit(X_train, y_train)
print("Done!")

# %%
y_pred = rf_pipeline.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc:.4f}")

# %% [markdown]
# # PART C: COMPARISON

# %% [markdown]
# ### ❓ Question 8: Confusion Matrix
# Perfectly clean. Almost no errors.

# %% [markdown]
# ### ❓ Question 9: Misleading Metrics
# Accuracy is high AND Recall is high. This metric is trustworthy here.

# %% [markdown]
# ### ❓ Question 10: Recommendation
# **WINNER.** Use Random Forest for all production needs.

# %% [markdown]
# ### ❓ Question 11: Improvements
# 1. **XGBoost**: Faster, sometimes better.
# 2. **More Data**: Forest loves data.
