# %% [markdown]
# # Problem Statement
#
# Nested CV compute + honest estimation: You have a dataset of 12,000 samples and plan to estimate performance using nested cross-validation. The outer loop uses 5 folds. Inside each outer-training split, you run an inner 4-fold CV grid search over 18 hyperparameter combinations. You train 1 model per fold per hyperparameter combo. Each training run takes 7 minutes on your GPU. Additionally, after selecting the best hyperparameters for each outer fold, you retrain once on the full outer-training split (so 1 extra training run per outer fold) which takes 10 minutes each.
#
# **(a) Compute the total number of training runs.**
# **(b) Compute total training time in hours.**
# **(c) If you reduce the grid from 18 to 10 combinations, recompute (a) and (b) and report the % time saved.**
#
# ## Steps to Solve
# 1. Define parameters (folds, combos, times).
# 2. Calculate inner loop runs and time.
# 3. Calculate refit runs and time.
# 4. Sum for total cost.
# 5. Compare two scenarios (18 vs 10 combos).
#
# ## Expected Output
# We expect to see the total number of runs (integer) and total time (hours, float) for both scenarios, followed by the percentage reduction in time.

# %% [markdown]
# ### Code Explanation: `OUTER_FOLDS = 5`
#
# **2.1 What the line of code does**: Sets the variable for number of outer folds to 5.
# **2.2 Why it is used**: Requirement from problem statement "outer loop uses 5 folds".
# **2.3 When to used**: Initialization of constants.
# **2.4 Where to use**: Global scope.
# **2.5 How to use**: Assignment.
# **2.6 How it works**: Stores integer 5 in memory.
# **2.7 Output with sample examples**: None (Assignment).
# **4. Explain Expected Output**: 5 stored in OUTER_FOLDS

# %%
OUTER_FOLDS = 5

# %% [markdown]
# ### Code Explanation: `INNER_FOLDS = 4`
#
# **2.1 What the line of code does**: Sets the variable for number of inner folds to 4.
# **2.2 Why it is used**: Requirement from problem statement "inner 4-fold CV".
# **2.3 When to used**: Initialization of constants.
# **2.4 Where to use**: Global scope.
# **2.5 How to use**: Assignment.
# **2.6 How it works**: Stores integer 4.
# **2.7 Output with sample examples**: None.
# **4. Explain Expected Output**: 4 stored in INNER_FOLDS

# %%
INNER_FOLDS = 4

# %% [markdown]
# ### Code Explanation: `TRAIN_TIME_MIN = 7`
#
# **2.1 What the line of code does**: Sets training time per fold in minutes.
# **2.2 Why it is used**: Requirement "Each training run takes 7 minutes".
# **2.3 When to used**: Initialization.
# **2.4 Where to use**: Global scope.
# **2.5 How to use**: Assignment.
# **2.6 How it works**: Stores integer 7.
# **2.7 Output with sample examples**: None.
# **4. Explain Expected Output**: 7 stored

# %%
TRAIN_TIME_MIN = 7

# %% [markdown]
# ### Code Explanation: `REFIT_TIME_MIN = 10`
#
# **2.1 What the line of code does**: Sets refit time per outer fold in minutes.
# **2.2 Why it is used**: Requirement "retrain... takes 10 minutes".
# **2.3 When to used**: Initialization.
# **2.4 Where to use**: Global scope.
# **2.5 How to use**: Assignment.
# **2.6 How it works**: Stores integer 10.
# **2.7 Output with sample examples**: None.
# **4. Explain Expected Output**: 10 stored

# %%
REFIT_TIME_MIN = 10

# %% [markdown]
# ### Code Explanation: `PARAM_COMBOS_A = 18`
#
# **2.1 What the line of code does**: Sets hyperparameter combinations for Scenario A.
# **2.2 Why it is used**: First scenario requirement.
# **2.3 When to used**: Definition of experiment A.
# **2.4 Where to use**: Global scope.
# **2.5 How to use**: Assignment.
# **2.6 How it works**: Stores 18.
# **2.7 Output with sample examples**: None.
# **4. Explain Expected Output**: 18 stored

# %%
PARAM_COMBOS_A = 18

# %% [markdown]
# ### Code Explanation: Inner Runs Calculation
#
# **2.1 What the line of code does**: Calculates total inner runs by multiplying outer folds, inner folds, and parameter combos.
# **2.2 Why it is used**: To find the total number of models trained during the grid search phase.
# **2.3 When to used**: First calculation step.
# **2.4 Where to use**: Main logic.
# **2.5 How to use**: Multiplication.
# **2.6 How it works**: $5 * 4 * 18$.
# **2.7 Output with sample examples**: 360.
# **4. Explain Expected Output**: 360 runs

# %%
inner_runs_a = OUTER_FOLDS * INNER_FOLDS * PARAM_COMBOS_A

# %% [markdown]
# ### Code Explanation: Refit Runs Calculation
#
# **2.1 What the line of code does**: Assigns outer folds count to refit runs.
# **2.2 Why it is used**: One refit per outer fold.
# **2.3 When to used**: Second calculation step.
# **2.4 Where to use**: Main logic.
# **2.5 How to use**: Assignment.
# **2.6 How it works**: Stores 5.
# **2.7 Output with sample examples**: 5.
# **4. Explain Expected Output**: 5 runs

# %%
refit_runs_a = OUTER_FOLDS

# %% [markdown]
# ### Code Explanation: Total Runs Calculation
#
# **2.1 What the line of code does**: Sums inner and refit runs.
# **2.2 Why it is used**: To get total training count.
# **2.3 When to used**: Final step for runs.
# **2.4 Where to use**: Main logic.
# **2.5 How to use**: Addition.
# **2.6 How it works**: $360 + 5$.
# **2.7 Output with sample examples**: 365.
# **4. Explain Expected Output**: 365 runs

# %%
total_runs_a = inner_runs_a + refit_runs_a

# %% [markdown]
# ### Code Explanation: Inner Time Calculation
#
# **2.1 What the line of code does**: Calculates time for inner loops.
# **2.2 Why it is used**: To estimate inner loop duration.
# **2.3 When to used**: Time calculation.
# **2.4 Where to use**: Main logic.
# **2.5 How to use**: Multiplication.
# **2.6 How it works**: $360 runs * 7 min$.
# **2.7 Output with sample examples**: 2520.
# **4. Explain Expected Output**: 2520 minutes

# %%
inner_time_a = inner_runs_a * TRAIN_TIME_MIN

# %% [markdown]
# ### Code Explanation: Refit Time Calculation
#
# **2.1 What the line of code does**: Calculates time for refits.
# **2.2 Why it is used**: To estimate refit duration.
# **2.3 When to used**: Time calculation.
# **2.4 Where to use**: Main logic.
# **2.5 How to use**: Multiplication.
# **2.6 How it works**: $5 runs * 10 min$.
# **2.7 Output with sample examples**: 50.
# **4. Explain Expected Output**: 50 minutes

# %%
refit_time_a = refit_runs_a * REFIT_TIME_MIN

# %% [markdown]
# ### Code Explanation: Total Time (Min) Calculation
#
# **2.1 What the line of code does**: Sums inner and refit time.
# **2.2 Why it is used**: To get total duration in minutes.
# **2.3 When to used**: Time calculation.
# **2.4 Where to use**: Main logic.
# **2.5 How to use**: Addition.
# **2.6 How it works**: $2520 + 50$.
# **2.7 Output with sample examples**: 2570.
# **4. Explain Expected Output**: 2570 minutes

# %%
total_time_min_a = inner_time_a + refit_time_a

# %% [markdown]
# ### Code Explanation: Total Time (Hours) Calculation
#
# **2.1 What the line of code does**: Converts minutes to hours.
# **2.2 Why it is used**: To report in hours as requested.
# **2.3 When to used**: Final result formatting.
# **2.4 Where to use**: Main logic.
# **2.5 How to use**: Division.
# **2.6 How it works**: $2570 / 60$.
# **2.7 Output with sample examples**: 42.83.
# **4. Explain Expected Output**: ~42.83 hours

# %%
total_time_hours_a = total_time_min_a / 60

# %% [markdown]
# ### Code Explanation: Print Header A
#
# **2.1 What the line of code does**: Prints scenario A header.
# **2.7 Output with sample examples**: Header String.
# **4. Explain Expected Output**: Header text

# %%
print("--- Scenario A (18 Combinations) ---")

# %% [markdown]
# ### Code Explanation: Print Runs A
#
# **2.1 What the line of code does**: Prints total runs.
# **2.7 Output with sample examples**: "Total Training Runs: 365".
# **4. Explain Expected Output**: Runs string

# %%
print(f"Total Training Runs: {total_runs_a}")

# %% [markdown]
# ### Code Explanation: Print Hours A
#
# **2.1 What the line of code does**: Prints total hours.
# **2.7 Output with sample examples**: "Total Training Time: 42.83 hours".
# **4. Explain Expected Output**: Hours string

# %%
print(f"Total Training Time: {total_time_hours_a:.2f} hours")

# %% [markdown]
# ### Code Explanation: `PARAM_COMBOS_B = 10`
#
# **2.1 What the line of code does**: Sets combinations for Scenario B.
# **2.7 Output with sample examples**: 10.
# **4. Explain Expected Output**: 10 stored

# %%
PARAM_COMBOS_B = 10

# %% [markdown]
# ### Code Explanation: Inner Runs B
#
# **2.1 What the line of code does**: Calculates runs for 10 combos.
# **2.6 How it works**: $5 * 4 * 10$.
# **2.7 Output with sample examples**: 200.
# **4. Explain Expected Output**: 200 runs

# %%
inner_runs_b = OUTER_FOLDS * INNER_FOLDS * PARAM_COMBOS_B

# %% [markdown]
# ### Code Explanation: Total Runs B
#
# **2.1 What the line of code does**: Calculates total runs for B.
# **2.6 How it works**: $200 + 5$.
# **2.7 Output with sample examples**: 205.
# **4. Explain Expected Output**: 205 runs

# %%
total_runs_b = inner_runs_b + refit_runs_a

# %% [markdown]
# ### Code Explanation: Inner Time B
#
# **2.1 What the line of code does**: Calculates time for B inner loop.
# **2.6 How it works**: $200 * 7$.
# **2.7 Output with sample examples**: 1400.
# **4. Explain Expected Output**: 1400 minutes

# %%
inner_time_b = inner_runs_b * TRAIN_TIME_MIN

# %% [markdown]
# ### Code Explanation: Total Time B
#
# **2.1 What the line of code does**: Calculates total time for B.
# **2.6 How it works**: $1400 + 50$.
# **2.7 Output with sample examples**: 1450.
# **4. Explain Expected Output**: 1450 minutes

# %%
total_time_min_b = inner_time_b + refit_time_a

# %% [markdown]
# ### Code Explanation: Total Hours B
#
# **2.1 What the line of code does**: Converts B time to hours.
# **2.6 How it works**: $1450 / 60$.
# **2.7 Output with sample examples**: 24.17.
# **4. Explain Expected Output**: 24.17 hours

# %%
total_time_hours_b = total_time_min_b / 60

# %% [markdown]
# ### Code Explanation: Print Header B
#
# **2.1 What the line of code does**: Prints B header.
# **2.7 Output with sample examples**: Header string.
# **4. Explain Expected Output**: Header text

# %%
print("\n--- Scenario B (10 Combinations) ---")

# %% [markdown]
# ### Code Explanation: Print Runs B
#
# **2.1 What the line of code does**: Prints runs B.
# **2.7 Output with sample examples**: "Total Training Runs: 205".
# **4. Explain Expected Output**: Runs string

# %%
print(f"Total Training Runs: {total_runs_b}")

# %% [markdown]
# ### Code Explanation: Print Hours B
#
# **2.1 What the line of code does**: Prints hours B.
# **2.7 Output with sample examples**: "Total Training Time: 24.17 hours".
# **4. Explain Expected Output**: Hours string

# %%
print(f"Total Training Time: {total_time_hours_b:.2f} hours")

# %% [markdown]
# ### Code Explanation: Savings Calculation
#
# **2.1 What the line of code does**: Calculates percent saved.
# **2.6 How it works**: $(2570 - 1450) / 2570 * 100$.
# **2.7 Output with sample examples**: 43.58.
# **4. Explain Expected Output**: 43.58 percent

# %%
time_saved_pct = ((total_time_min_a - total_time_min_b) / total_time_min_a) * 100

# %% [markdown]
# ### Code Explanation: Print Savings
#
# **2.1 What the line of code does**: Prints savings.
# **2.7 Output with sample examples**: "Percentage Time Saved: 43.58%".
# **4. Explain Expected Output**: Savings string

# %%
print(f"Percentage Time Saved: {time_saved_pct:.2f}%")
